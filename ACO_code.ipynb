# %%
import random

# Parameters
student_groups = ['IF-47-01', 'IF-47-02', 'IF-47-03', 'IF-47-04', 'IF-47-05', 'IF-47-06']
permanent_lectures = ['DOK', 'FAZ', 'GMO', 'IDV', 'SBG', 'PHG', 'ADE', 'AZN', 'DDR', 'DNS', 'DQU', 'DRI', 'DTO']
non_permanent_lectures = ['ALH', 'ALZ', 'APY', 'ASA', 'BRV', 'BTG', 'CDF', 'DAM', 'DRB', 'DVI', 'DWD', 'EDW']
lecturers = permanent_lectures + non_permanent_lectures
rooms = ['TULT-0601', 'TULT-0602', 'TULT-0603', 'TULT-0701', 'TULT-0702', 'TULT-0703', 'TULT-0706', 'TULT-0707', 'TULT-0709', 'TULT-1507', 'TULT-1509', 'TULT-1510']
timeslots = ['timeslot1', 'timeslot2', 'timeslot3', 'timeslot4', 'timeslot5', 'timeslot6', 'timeslot7', 'timeslot8', 'timeslot9', 'timeslot10', 'timeslot11']
courses = ['UKJXB2', 'UAJXA2', 'CII1E3', 'CII1A3', 'CII1C2', 'CII1B3', 'CII1D3', 'CTJ1A2', 'CRI1A2', 'CRI1B3', 'CSI1A2']
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

# Hyperparameters
num_ants = 10
num_iterations = 100
decay = 0.5
alpha = 1
beta = 2

# Initial pheromone levels
pheromone = [[[1 for _ in timeslots] for _ in rooms] for _ in days]
pheromone_lecturer = {lecturer: 1 for lecturer in lecturers}

# Define the fitness function
def fitness(schedule):
    penalty = 0
    room_timeslot_usage = {}
    lecturer_course_group = {}
    timeslot_count = {room: {day: 0 for day in days} for room in rooms}
    
    for group in schedule:
        for (course, day, room, timeslot, lecturer) in schedule[group]:
            # Check room usage
            if (day, room, timeslot) in room_timeslot_usage:
                penalty += 1
            else:
                room_timeslot_usage[(day, room, timeslot)] = group
                timeslot_count[room][day] += 1

            # Check lecturer constraints
            if (lecturer, course, group) in lecturer_course_group:
                penalty += 1
            else:
                lecturer_course_group[(lecturer, course, group)] = True

    # Penalty for empty timeslots and unbalanced room usage
    for room in rooms:
        for day in days:
            penalty += (len(timeslots) - timeslot_count[room][day]) * 0.1  # Less penalty for fewer empty slots

    return penalty

# Create the initial population
def create_schedule():
    schedule = {}
    for group in student_groups:
        schedule[group] = []
        for course in courses:
            day = random.choice(days)
            room = random.choice(rooms)
            timeslot = random.choice(timeslots)
            lecturer = random.choice(lecturers)
            schedule[group].append((course, day, room, timeslot, lecturer))
    return schedule

# Update pheromones
def update_pheromones(pheromone, pheromone_lecturer, all_schedules):
    for day in range(len(days)):
        for room in range(len(rooms)):
            for timeslot in range(len(timeslots)):
                pheromone[day][room][timeslot] *= decay
                for schedule in all_schedules:
                    if is_course_scheduled(schedule, day, room, timeslot):
                        pheromone[day][room][timeslot] += 1 / (1 + fitness(schedule))
    
    for lecturer in lecturers:
        pheromone_lecturer[lecturer] *= decay
        for schedule in all_schedules:
            if is_lecturer_scheduled(schedule, lecturer):
                pheromone_lecturer[lecturer] += 1 / (1 + fitness(schedule))

    return pheromone, pheromone_lecturer

# Check if a course is scheduled
def is_course_scheduled(schedule, day, room, timeslot):
    for group in schedule:
        for (course, d, r, t, lecturer) in schedule[group]:
            if d == days[day] and r == rooms[room] and t == timeslots[timeslot]:
                return True
    return False

# Check if a lecturer is scheduled
def is_lecturer_scheduled(schedule, lecturer):
    for group in schedule:
        for (course, day, room, timeslot, l) in schedule[group]:
            if l == lecturer:
                return True
    return False

# Main ACO loop
def aco():
    best_schedule = None
    best_fitness = float('inf')
    for iteration in range(num_iterations):
        all_schedules = []
        for ant in range(num_ants):
            schedule = create_schedule()
            all_schedules.append(schedule)
            fit = fitness(schedule)
            if fit < best_fitness:
                best_fitness = fit
                best_schedule = schedule
        update_pheromones(pheromone, pheromone_lecturer, all_schedules)
    return best_schedule, best_fitness

# Display the best schedule in a timetable form
def print_timetable_by_room(schedule):
    timetable = {room: {day: {timeslot: None for timeslot in timeslots} for day in days} for room in rooms}
    for group in schedule:
        for (course, day, room, timeslot, lecturer) in schedule[group]:
            timetable[room][day][timeslot] = (course, group, lecturer)

    for room in rooms:
        print(f"Timetable for {room}:")
        for day in days:
            print(f"  {day}:")
            for timeslot in timeslots:
                entry = timetable[room][day][timeslot]
                if entry:
                    course, group, lecturer = entry
                    print(f"    {timeslot}: {course} for {group} with {lecturer}")
                else:
                    print(f"    {timeslot}: Free")
        print()

best_schedule, best_fitness = aco()
print_timetable_by_room(best_schedule)
print("Best Fitness:", best_fitness)
# Out:
# Timetable for TULT-0601:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: CII1B3 for IF-47-03 with SBG
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CII1C2 for IF-47-02 with EDW
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Thursday:
#     timeslot1: CII1C2 for IF-47-03 with DQU
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: UAJXA2 for IF-47-05 with IDV
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: UKJXB2 for IF-47-05 with CDF
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CSI1A2 for IF-47-02 with GMO
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#
# Timetable for TULT-0602:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CII1E3 for IF-47-04 with BTG
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CII1E3 for IF-47-05 with BRV
#     timeslot10: Free
#     timeslot11: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CII1C2 for IF-47-01 with ALZ
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#
# Timetable for TULT-0603:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1D3 for IF-47-06 with IDV
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: CRI1A2 for IF-47-02 with DOK
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CTJ1A2 for IF-47-05 with ALZ
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CTJ1A2 for IF-47-01 with GMO
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: UKJXB2 for IF-47-04 with DNS
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: UKJXB2 for IF-47-03 with DRB
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: UKJXB2 for IF-47-02 with PHG
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#
# Timetable for TULT-0701:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: UAJXA2 for IF-47-06 with GMO
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1B3 for IF-47-02 with PHG
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CRI1A2 for IF-47-04 with SBG
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Thursday:
#     timeslot1: UAJXA2 for IF-47-04 with DRI
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CII1B3 for IF-47-05 with DQU
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CII1A3 for IF-47-04 with DVI
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: CRI1A2 for IF-47-03 with SBG
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#
# Timetable for TULT-0702:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CII1A3 for IF-47-03 with BTG
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: CSI1A2 for IF-47-03 with DRB
#     timeslot11: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CII1A3 for IF-47-05 with EDW
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CTJ1A2 for IF-47-03 with ASA
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CSI1A2 for IF-47-01 with SBG
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: UAJXA2 for IF-47-02 with DWD
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: CTJ1A2 for IF-47-02 with CDF
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#
# Timetable for TULT-0703:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CRI1B3 for IF-47-01 with DAM
#     timeslot9: CII1C2 for IF-47-05 with ALZ
#     timeslot10: Free
#     timeslot11: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: UKJXB2 for IF-47-01 with DOK
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CSI1A2 for IF-47-05 with DRB
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Thursday:
#     timeslot1: UKJXB2 for IF-47-06 with FAZ
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CII1A3 for IF-47-06 with DDR
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: CRI1A2 for IF-47-05 with FAZ
#     timeslot11: Free
#
# Timetable for TULT-0706:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CII1E3 for IF-47-03 with ALH
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#
# Timetable for TULT-0707:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CRI1B3 for IF-47-05 with BRV
#     timeslot8: Free
#     timeslot9: CRI1B3 for IF-47-04 with EDW
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1D3 for IF-47-05 with FAZ
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: CRI1B3 for IF-47-06 with PHG
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CRI1B3 for IF-47-03 with EDW
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: CII1D3 for IF-47-01 with DRI
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CTJ1A2 for IF-47-06 with FAZ
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#
# Timetable for TULT-0709:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CSI1A2 for IF-47-06 with DTO
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: UAJXA2 for IF-47-03 with DNS
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: UAJXA2 for IF-47-01 with DQU
#     timeslot11: CII1E3 for IF-47-06 with GMO
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CII1B3 for IF-47-01 with AZN
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CRI1A2 for IF-47-06 with DAM
#     timeslot6: Free
#     timeslot7: CII1B3 for IF-47-06 with DAM
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: CSI1A2 for IF-47-04 with IDV
#     timeslot11: Free
#
# Timetable for TULT-1507:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1D3 for IF-47-04 with FAZ
#     timeslot4: CTJ1A2 for IF-47-04 with DAM
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CRI1A2 for IF-47-01 with DQU
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1C2 for IF-47-04 with ALZ
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: CII1D3 for IF-47-02 with APY
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CII1B3 for IF-47-04 with GMO
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CRI1B3 for IF-47-02 with DVI
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#
# Timetable for TULT-1509:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: CII1E3 for IF-47-01 with FAZ
#     timeslot7: CII1D3 for IF-47-03 with APY
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CII1A3 for IF-47-01 with ASA
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Wednesday:
#     timeslot1: CII1A3 for IF-47-02 with IDV
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CII1E3 for IF-47-02 with DVI
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: CII1C2 for IF-47-06 with SBG
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#
# Timetable for TULT-1510:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#
# Best Fitness: 72.59999999999997

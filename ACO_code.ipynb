# %%
import random
import pandas as pd

# %%
room_excel = pd.read_excel("Dataset/Gedung TULT.xlsx", usecols=['Nama Ruangan'])
room_list = room_excel['Nama Ruangan'].tolist()
room_list
# Out:
# ['TULT-0601',
#  'TULT-0602',
#  'TULT-0603',
#  'TULT-0701',
#  'TULT-0702',
#  'TULT-0703',
#  'TULT-0706',
#  'TULT-0707',
#  'TULT-0709',
#  'TULT-0710',
#  'TULT-0711',
#  'TULT-0714',
#  'TULT-0715',
#  'TULT-0716',
#  'TULT-1507',
#  'TULT-1509',
#  'TULT-1510']

# %%
class_excel = pd.read_excel("Dataset/Kelas FIF.xlsx", sheet_name="Kelas FIF", usecols=['Kelas FIF'])
class_list = class_excel['Kelas FIF'].tolist()
class_list
# Out:
# ['IF-47-01',
#  'IF-47-02',
#  'IF-47-03',
#  'IF-47-04',
#  'IF-47-05',
#  'IF-47-06',
#  'IF-47-07',
#  'IF-47-08',
#  'IF-47-09',
#  'IF-47-10',
#  'IF-47-11',
#  'IF-47-12',
#  'IF-47-INT',
#  'IT-47-01',
#  'IT-47-02',
#  'IT-47-03',
#  'IT-47-04',
#  'SE-47-01',
#  'SE-47-02',
#  'SE-47-03',
#  'SE-47-04',
#  'DS-47-01',
#  'DS-47-02',
#  'DS-47-03']

# %%
subject_excel = pd.read_excel("Dataset/Mata Kuliah FIF.xlsx", sheet_name="FIF Semester 1", usecols=['Kode'])
subject_list = subject_excel['Kode'].tolist()
subject_list
# Out:
# ['UKJXB2',
#  'UAJXA2',
#  'CII1E3',
#  'CII1A3',
#  'CII1C2',
#  'CII1B3',
#  'CII1D3 ',
#  'CTJ1A2',
#  'CRI1A2',
#  'CRI1B3',
#  'CSI1A2']

# %%
# Read the dataset and filter by status
dosen_dataset = pd.read_excel("Dataset/data dosen.xlsx", sheet_name="all dosen", usecols=['Kode', 'Status'])

# %%
rooms = room_list
students_groups = class_list
subjects = subject_list
permanent_lectures = dosen_dataset.loc[dosen_dataset['Status'] == 1, 'Kode'].tolist()
non_permanent_lectures = dosen_dataset.loc[dosen_dataset['Status'] == 0, 'Kode'].tolist()
lecturers = permanent_lectures + non_permanent_lectures
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
timeslots = ['timeslot1', 'timeslot2', 'timeslot3', 'timeslot4', 'timeslot5', 'timeslot6', 'timeslot7', 'timeslot8', 'timeslot9', 'timeslot10', 'timeslot11', 'timeslot12']

# %%
# Hyperparameters
num_ants = 10
num_iterations = 100
decay = 0.5
alpha = 1
beta = 2

# %%
# Hyperparameters
num_ants = 10
num_iterations = 100
decay = 0.5
alpha = 1
beta = 2

# %%
# Timeslots to minimize usage
undesirable_timeslots = ['timeslot1', 'timeslot5', 'timeslot6', 'timeslot11']

# Initial pheromone levels
pheromone = [[[1 for _ in timeslots] for _ in rooms] for _ in days]
pheromone_lecturer = {lecturer: 1 for lecturer in lecturers}

# Define the fitness function
def fitness(schedule):
    penalty = 0
    room_timeslot_usage = {}
    lecturer_course_group = {}
    timeslot_count = {room: {day: 0 for day in days} for room in rooms}
    group_timeslot_count = {group: {day: 0 for day in days} for group in students_groups}

    room_conflicts = 0
    lecturer_conflicts = 0
    undesirable_timeslot_penalty = 0
    empty_timeslot_penalty = 0
    specific_rules_penalty = 0

    for group in schedule:
        for (course, day, room, timeslot, lecturer) in schedule[group]:
            # Check room usage
            if (day, room, timeslot) in room_timeslot_usage:
                room_conflicts += 1
            else:
                room_timeslot_usage[(day, room, timeslot)] = group
                timeslot_count[room][day] += 1
                group_timeslot_count[group][day] += 1

            # Check lecturer constraints
            if (lecturer, course, group) in lecturer_course_group:
                lecturer_conflicts += 1
            else:
                lecturer_course_group[(lecturer, course, group)] = True

            # Additional penalty for undesirable timeslots
            if timeslot in undesirable_timeslots:
                undesirable_timeslot_penalty += 0.5

            # Specific rule: No permanent lecturers on timeslot4, timeslot5, timeslot6 on Thursdays
            if day == 'Thursday' and timeslot in ['timeslot4', 'timeslot5', 'timeslot6'] and lecturer in permanent_lectures:
                specific_rules_penalty += 1

            # Specific rule: No courses in timeslot5 and timeslot6 on Friday
            if day == 'Friday' and timeslot in ['timeslot5', 'timeslot6']:
                specific_rules_penalty += 1

            # Specific rule: Rooms TULT-1507, TULT-1509, TULT-1510 only for IF-47-INT
            if room in ['TULT-1507', 'TULT-1509', 'TULT-1510'] and group != 'IF-47-INT':
                specific_rules_penalty += 1

            # One course per timeslot per day per group
            if group_timeslot_count[group][day] > 1:
                specific_rules_penalty += 1

    # Penalty for empty timeslots and unbalanced room usage
    for room in rooms:
        for day in days:
            empty_timeslot_penalty += (len(timeslots) - timeslot_count[room][day]) * 0.1  # Less penalty for fewer empty slots

    total_penalty = (room_conflicts + lecturer_conflicts + undesirable_timeslot_penalty + empty_timeslot_penalty + specific_rules_penalty)

    return total_penalty

# %%
# Create the initial population
def create_schedule():
    schedule = {group: [] for group in students_groups}
    for group in students_groups:
        for course in subjects:
            try:
                course_length = int(course[-1])  # Get the length of the course from the last digit
            except ValueError:
                continue  # Skip if the course code does not end with a digit

            while True:
                day = random.choice(days)
                room = random.choice(rooms)
                start_timeslot_index = random.randint(0, len(timeslots) - course_length)
                timeslot_range = timeslots[start_timeslot_index:start_timeslot_index + course_length]
                lecturer = random.choice(lecturers)

                if any([(day, room, timeslot) in [(d, r, t) for c, d, r, t, l in schedule[group]] for timeslot in timeslot_range]):
                    continue  # Skip if any timeslot in the range is already taken

                if (room in ['TULT-1507', 'TULT-1509', 'TULT-1510'] and group == 'IF-47-INT'):
                    continue  # Skip if room restriction is violated

                if (day == 'Thursday' and any(timeslot in ['timeslot4', 'timeslot5', 'timeslot6'] for timeslot in timeslot_range) and lecturer in permanent_lectures):
                    continue  # Skip if permanent lecturer rule is violated

                if (day == 'Friday' and any(timeslot in ['timeslot5', 'timeslot6'] for timeslot in timeslot_range)):
                    continue  # Skip if Friday timeslot rule is violated

                for timeslot in timeslot_range:
                    schedule[group].append((course, day, room, timeslot, lecturer))
                break
    return schedule

# %%
# Update pheromones
def update_pheromones(pheromone, pheromone_lecturer, all_schedules):
    for day in range(len(days)):
        for room in range(len(rooms)):
            for timeslot in range(len(timeslots)):
                pheromone[day][room][timeslot] *= decay
                for schedule in all_schedules:
                    if is_course_scheduled(schedule, day, room, timeslot):
                        pheromone[day][room][timeslot] += 1 / (1 + fitness(schedule))
    
    for lecturer in lecturers:
        pheromone_lecturer[lecturer] *= decay
        for schedule in all_schedules:
            if is_lecturer_scheduled(schedule, lecturer):
                pheromone_lecturer[lecturer] += 1 / (1 + fitness(schedule))

    return pheromone, pheromone_lecturer

# Check if a course is scheduled
def is_course_scheduled(schedule, day, room, timeslot):
    for group in schedule:
        for (course, d, r, t, lecturer) in schedule[group]:
            if d == days[day] and r == rooms[room] and t == timeslots[timeslot]:
                return True
    return False

# Check if a lecturer is scheduled
def is_lecturer_scheduled(schedule, lecturer):
    for group in schedule:
        for (course, day, room, timeslot, l) in schedule[group]:
            if l == lecturer:
                return True
    return False

# Main ACO loop
def aco():
    best_schedule = None
    best_fitness = float('inf')
    for iteration in range(num_iterations):
        all_schedules = []
        for ant in range(num_ants):
            schedule = create_schedule()
            all_schedules.append(schedule)
            fit = fitness(schedule)
            if fit < best_fitness:
                best_fitness = fit
                best_schedule = schedule
        update_pheromones(pheromone, pheromone_lecturer, all_schedules)
    return best_schedule, best_fitness

# %%
# Display the best schedule in a timetable form categorized by room
def print_timetable_by_room(schedule):
    timetable = {room: {day: {timeslot: None for timeslot in timeslots} for day in days} for room in rooms}
    for group in schedule:
        for (course, day, room, timeslot, lecturer) in schedule[group]:
            timetable[room][day][timeslot] = (course, group, lecturer)

    for room in rooms:
        print(f"Timetable for {room}:")
        for day in days:
            print(f"  {day}:")
            for timeslot in timeslots:
                entry = timetable[room][day][timeslot]
                if entry:
                    course, group, lecturer = entry
                    print(f"    {timeslot}: {course} for {group} with {lecturer}")
                else:
                    print(f"    {timeslot}: Free")
        print()

best_schedule, best_fitness = aco()
print_timetable_by_room(best_schedule)
print("Best Fitness:", best_fitness)
# Out:
# Timetable for TULT-0601:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CRI1B3 for IT-47-01 with DRI
#     timeslot4: CRI1B3 for IT-47-01 with DRI
#     timeslot5: CII1A3 for SE-47-04 with DYA
#     timeslot6: CII1A3 for SE-47-04 with DYA
#     timeslot7: CII1A3 for SE-47-04 with DYA
#     timeslot8: CII1C2 for SE-47-02 with AZN
#     timeslot9: CII1E3 for IF-47-10 with FMH
#     timeslot10: Free
#     timeslot11: CSI1A2 for IF-47-08 with BRV
#     timeslot12: CSI1A2 for IF-47-08 with BRV
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: UAJXA2 for IF-47-11 with ADE
#     timeslot6: UAJXA2 for IF-47-11 with ADE
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: UKJXB2 for IF-47-07 with ALH
#     timeslot12: UKJXB2 for IF-47-07 with ALH
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CRI1B3 for SE-47-04 with IPL
#     timeslot4: CRI1B3 for SE-47-04 with IPL
#     timeslot5: CTJ1A2 for DS-47-01 with ASA
#     timeslot6: CTJ1A2 for DS-47-01 with ASA
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CRI1B3 for DS-47-02 with DDR
#     timeslot10: CRI1B3 for DS-47-02 with DDR
#     timeslot11: CRI1B3 for DS-47-02 with DDR
#     timeslot12: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CRI1B3 for IF-47-INT with ALZ
#     timeslot10: CRI1B3 for IF-47-INT with ALZ
#     timeslot11: CRI1B3 for IF-47-INT with ALZ
#     timeslot12: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: CII1B3 for IF-47-11 with FAZ
#     timeslot3: CII1B3 for IF-47-11 with FAZ
#     timeslot4: CII1B3 for IF-47-11 with FAZ
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CRI1B3 for DS-47-03 with EDW
#     timeslot8: CRI1B3 for DS-47-03 with EDW
#     timeslot9: CRI1B3 for DS-47-03 with EDW
#     timeslot10: Free
#     timeslot11: CTJ1A2 for IF-47-02 with ASA
#     timeslot12: CTJ1A2 for IF-47-02 with ASA
#
# Timetable for TULT-0602:
#   Monday:
#     timeslot1: Free
#     timeslot2: CTJ1A2 for SE-47-04 with EDW
#     timeslot3: CTJ1A2 for SE-47-04 with EDW
#     timeslot4: CII1C2 for SE-47-01 with HMT
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: CII1A3 for IT-47-02 with DOK
#     timeslot11: CII1A3 for IT-47-02 with DOK
#     timeslot12: CII1A3 for IT-47-02 with DOK
#   Tuesday:
#     timeslot1: CSI1A2 for IF-47-INT with IDV
#     timeslot2: CSI1A2 for IF-47-INT with IDV
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CII1E3 for DS-47-02 with BTG
#     timeslot8: CII1E3 for DS-47-02 with BTG
#     timeslot9: CII1E3 for DS-47-02 with BTG
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: UAJXA2 for IT-47-04 with DQU
#     timeslot5: UAJXA2 for IT-47-04 with DQU
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CII1C2 for IT-47-04 with DAM
#     timeslot9: CII1C2 for IT-47-04 with DAM
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: CII1E3 for IT-47-01 with CDF
#     timeslot3: CII1E3 for IT-47-01 with CDF
#     timeslot4: CII1E3 for IT-47-01 with CDF
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CII1C2 for IT-47-03 with CDF
#     timeslot9: CII1E3 for SE-47-01 with IMD
#     timeslot10: CII1E3 for SE-47-01 with IMD
#     timeslot11: CII1E3 for SE-47-01 with IMD
#     timeslot12: CII1C2 for IF-47-10 with DQU
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: CSI1A2 for IF-47-09 with DWF
#     timeslot7: CSI1A2 for IF-47-09 with DWF
#     timeslot8: CTJ1A2 for IF-47-INT with FKI
#     timeslot9: CTJ1A2 for IF-47-INT with FKI
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-0603:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: UKJXB2 for IF-47-08 with FKI
#     timeslot7: UKJXB2 for IF-47-08 with FKI
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CII1B3 for SE-47-04 with AZN
#     timeslot5: CII1B3 for SE-47-04 with AZN
#     timeslot6: CII1B3 for SE-47-04 with AZN
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: UAJXA2 for IF-47-09 with HMT
#     timeslot11: UAJXA2 for IF-47-09 with HMT
#     timeslot12: Free
#   Thursday:
#     timeslot1: CII1C2 for IT-47-02 with IPL
#     timeslot2: CII1C2 for IT-47-02 with IPL
#     timeslot3: CII1A3 for IF-47-01 with KMM
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: CII1E3 for SE-47-04 with DDR
#     timeslot3: CII1E3 for SE-47-04 with DDR
#     timeslot4: CII1E3 for SE-47-04 with DDR
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: UAJXA2 for IT-47-01 with ADE
#     timeslot8: UAJXA2 for IT-47-01 with ADE
#     timeslot9: CSI1A2 for IF-47-10 with AZN
#     timeslot10: UKJXB2 for IT-47-04 with DWD
#     timeslot11: UKJXB2 for IT-47-04 with DWD
#     timeslot12: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CII1C2 for SE-47-04 with DRI
#     timeslot8: CII1C2 for SE-47-04 with DRI
#     timeslot9: UKJXB2 for IF-47-06 with DNS
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-0701:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CRI1A2 for IF-47-05 with DNS
#     timeslot4: CRI1A2 for IF-47-05 with DNS
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: CSI1A2 for IF-47-07 with CDF
#     timeslot12: CSI1A2 for IF-47-07 with CDF
#   Tuesday:
#     timeslot1: Free
#     timeslot2: UKJXB2 for IF-47-12 with DWD
#     timeslot3: UKJXB2 for IF-47-12 with DWD
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: CRI1A2 for IF-47-03 with PHG
#     timeslot7: CRI1A2 for IF-47-03 with PHG
#     timeslot8: CII1C2 for SE-47-03 with FKI
#     timeslot9: CII1C2 for SE-47-03 with FKI
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: CII1A3 for IF-47-02 with EDW
#     timeslot3: CII1A3 for IF-47-02 with EDW
#     timeslot4: UKJXB2 for SE-47-03 with EDW
#     timeslot5: UKJXB2 for SE-47-03 with EDW
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CRI1A2 for IT-47-02 with DYA
#     timeslot8: CRI1A2 for IT-47-02 with DYA
#     timeslot9: CII1C2 for IF-47-01 with IPL
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CSI1A2 for IT-47-03 with ALH
#     timeslot4: CSI1A2 for IT-47-03 with ALH
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-0702:
#   Monday:
#     timeslot1: CTJ1A2 for DS-47-02 with DDR
#     timeslot2: CTJ1A2 for DS-47-02 with DDR
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CII1B3 for DS-47-02 with JDN
#     timeslot8: CII1B3 for DS-47-02 with JDN
#     timeslot9: CII1B3 for DS-47-02 with JDN
#     timeslot10: CII1A3 for SE-47-02 with BTG
#     timeslot11: CII1A3 for SE-47-02 with BTG
#     timeslot12: CII1A3 for SE-47-02 with BTG
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: UAJXA2 for DS-47-01 with FKI
#     timeslot6: UAJXA2 for DS-47-01 with FKI
#     timeslot7: CRI1B3 for IT-47-04 with BRV
#     timeslot8: CRI1B3 for IT-47-04 with BRV
#     timeslot9: Free
#     timeslot10: CRI1B3 for IF-47-02 with ADE
#     timeslot11: CRI1B3 for IF-47-02 with ADE
#     timeslot12: CRI1B3 for IF-47-02 with ADE
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: UKJXB2 for DS-47-03 with NIK
#     timeslot8: UKJXB2 for DS-47-03 with NIK
#     timeslot9: CRI1A2 for DS-47-02 with NIK
#     timeslot10: Free
#     timeslot11: UKJXB2 for DS-47-02 with GMO
#     timeslot12: UKJXB2 for DS-47-02 with GMO
#   Thursday:
#     timeslot1: Free
#     timeslot2: CRI1B3 for IF-47-05 with DVI
#     timeslot3: CRI1B3 for IF-47-05 with DVI
#     timeslot4: CRI1B3 for IF-47-05 with DVI
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: UKJXB2 for IF-47-01 with IPL
#     timeslot9: UKJXB2 for IF-47-01 with IPL
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CRI1B3 for IF-47-06 with ASA
#     timeslot9: CRI1B3 for IF-47-06 with ASA
#     timeslot10: CRI1B3 for IF-47-06 with ASA
#     timeslot11: Free
#     timeslot12: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: CRI1A2 for SE-47-01 with ERW
#     timeslot3: CRI1A2 for SE-47-01 with ERW
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-0703:
#   Monday:
#     timeslot1: CTJ1A2 for IT-47-04 with KMM
#     timeslot2: CTJ1A2 for IT-47-04 with KMM
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CII1B3 for IF-47-07 with DNS
#     timeslot6: CII1B3 for IF-47-07 with DNS
#     timeslot7: CII1E3 for IF-47-INT with DRB
#     timeslot8: CII1C2 for DS-47-01 with DWF
#     timeslot9: CII1C2 for DS-47-01 with DWF
#     timeslot10: Free
#     timeslot11: UKJXB2 for SE-47-01 with HMT
#     timeslot12: UKJXB2 for SE-47-01 with HMT
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CII1A3 for IF-47-06 with IPL
#     timeslot6: UKJXB2 for IT-47-03 with FAZ
#     timeslot7: UKJXB2 for IT-47-03 with FAZ
#     timeslot8: UKJXB2 for IF-47-INT with DVI
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: CII1A3 for IF-47-03 with ASA
#     timeslot2: CII1A3 for IF-47-03 with ASA
#     timeslot3: CII1A3 for IF-47-03 with ASA
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: CII1E3 for IT-47-02 with EDW
#     timeslot3: CII1E3 for IT-47-02 with EDW
#     timeslot4: CII1E3 for IT-47-02 with EDW
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CSI1A2 for IF-47-06 with IPL
#     timeslot9: CII1B3 for SE-47-03 with IND
#     timeslot10: CII1B3 for SE-47-03 with IND
#     timeslot11: CII1B3 for SE-47-03 with IND
#     timeslot12: CTJ1A2 for IT-47-01 with DVI
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CII1C2 for IF-47-12 with PHG
#     timeslot9: CII1C2 for IF-47-12 with PHG
#     timeslot10: CII1E3 for IT-47-03 with APY
#     timeslot11: CII1E3 for IT-47-03 with APY
#     timeslot12: CII1E3 for IT-47-03 with APY
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CII1E3 for IT-47-04 with EDW
#     timeslot5: CII1E3 for IT-47-04 with EDW
#     timeslot6: CII1E3 for IT-47-04 with EDW
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-0706:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1C2 for DS-47-03 with DRI
#     timeslot4: CII1C2 for DS-47-03 with DRI
#     timeslot5: CTJ1A2 for SE-47-03 with DRB
#     timeslot6: CTJ1A2 for SE-47-03 with DRB
#     timeslot7: CII1A3 for IF-47-05 with SBG
#     timeslot8: CII1A3 for IF-47-05 with SBG
#     timeslot9: CSI1A2 for IT-47-01 with ADE
#     timeslot10: CSI1A2 for IT-47-01 with ADE
#     timeslot11: CRI1A2 for IT-47-01 with DWF
#     timeslot12: CRI1A2 for IT-47-01 with DWF
#   Tuesday:
#     timeslot1: Free
#     timeslot2: CII1C2 for IF-47-05 with DVI
#     timeslot3: CRI1A2 for IF-47-10 with AZN
#     timeslot4: CRI1A2 for IF-47-10 with AZN
#     timeslot5: CII1E3 for SE-47-02 with ALH
#     timeslot6: CII1E3 for SE-47-02 with ALH
#     timeslot7: CII1E3 for SE-47-02 with ALH
#     timeslot8: CRI1B3 for DS-47-01 with DWD
#     timeslot9: CRI1B3 for DS-47-01 with DWD
#     timeslot10: CRI1B3 for DS-47-01 with DWD
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: CRI1B3 for IF-47-08 with DWD
#     timeslot7: CRI1B3 for IF-47-08 with DWD
#     timeslot8: CRI1B3 for IF-47-08 with DWD
#     timeslot9: Free
#     timeslot10: CII1E3 for DS-47-03 with FKI
#     timeslot11: CII1E3 for DS-47-03 with FKI
#     timeslot12: CII1E3 for DS-47-03 with FKI
#   Thursday:
#     timeslot1: CRI1A2 for IF-47-12 with DWF
#     timeslot2: CRI1A2 for IF-47-12 with DWF
#     timeslot3: CSI1A2 for IF-47-05 with ERW
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: UKJXB2 for IF-47-05 with DVI
#     timeslot10: UKJXB2 for IF-47-05 with DVI
#     timeslot11: Free
#     timeslot12: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: CRI1A2 for DS-47-01 with FAZ
#     timeslot3: CRI1A2 for DS-47-01 with FAZ
#     timeslot4: CII1B3 for IF-47-09 with AZN
#     timeslot5: CSI1A2 for IT-47-04 with DRB
#     timeslot6: CSI1A2 for IT-47-04 with DRB
#     timeslot7: UKJXB2 for IF-47-04 with CDF
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: UAJXA2 for IF-47-03 with SBG
#     timeslot11: UAJXA2 for IF-47-03 with SBG
#     timeslot12: Free
#
# Timetable for TULT-0707:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1A3 for IF-47-11 with DVI
#     timeslot4: CII1A3 for IF-47-11 with DVI
#     timeslot5: CII1A3 for IF-47-11 with DVI
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1E3 for IF-47-04 with FKI
#     timeslot4: CII1E3 for IF-47-04 with FKI
#     timeslot5: CII1E3 for IF-47-04 with FKI
#     timeslot6: UKJXB2 for IT-47-02 with FKI
#     timeslot7: UKJXB2 for IT-47-02 with FKI
#     timeslot8: CII1C2 for IF-47-09 with DTO
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CRI1B3 for IT-47-03 with NIK
#     timeslot10: CRI1B3 for IT-47-03 with NIK
#     timeslot11: CRI1B3 for IT-47-03 with NIK
#     timeslot12: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CRI1A2 for IF-47-06 with BRV
#     timeslot6: CRI1A2 for IF-47-06 with BRV
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: CSI1A2 for SE-47-04 with DDR
#     timeslot12: CSI1A2 for SE-47-04 with DDR
#   Saturday:
#     timeslot1: CTJ1A2 for DS-47-03 with DOK
#     timeslot2: CTJ1A2 for DS-47-03 with DOK
#     timeslot3: CRI1B3 for SE-47-02 with HMT
#     timeslot4: CRI1B3 for SE-47-02 with HMT
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-0709:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1A3 for DS-47-03 with IPL
#     timeslot4: CII1A3 for DS-47-03 with IPL
#     timeslot5: CII1A3 for DS-47-03 with IPL
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CSI1A2 for SE-47-02 with IND
#     timeslot9: CSI1A2 for SE-47-02 with IND
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CII1B3 for DS-47-03 with IDV
#     timeslot6: CII1B3 for DS-47-03 with IDV
#     timeslot7: CII1B3 for DS-47-03 with IDV
#     timeslot8: CTJ1A2 for IF-47-05 with IPL
#     timeslot9: CTJ1A2 for IF-47-05 with IPL
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: CRI1A2 for IF-47-11 with DYA
#     timeslot3: CRI1A2 for IF-47-11 with DYA
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CSI1A2 for DS-47-01 with DQU
#     timeslot9: CSI1A2 for DS-47-01 with DQU
#     timeslot10: CII1A3 for IF-47-08 with PHG
#     timeslot11: CII1A3 for IF-47-08 with PHG
#     timeslot12: CII1A3 for IF-47-08 with PHG
#   Thursday:
#     timeslot1: UAJXA2 for IF-47-10 with PHG
#     timeslot2: UAJXA2 for IF-47-10 with PHG
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: UKJXB2 for IF-47-03 with DYA
#     timeslot8: UKJXB2 for IF-47-03 with DYA
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: CII1C2 for IT-47-01 with APY
#     timeslot3: CII1C2 for IT-47-01 with APY
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CTJ1A2 for IF-47-10 with KMM
#     timeslot8: CSI1A2 for SE-47-01 with ALZ
#     timeslot9: CSI1A2 for SE-47-01 with ALZ
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: CII1A3 for IF-47-INT with JDN
#     timeslot7: CSI1A2 for DS-47-02 with DTO
#     timeslot8: CSI1A2 for DS-47-02 with DTO
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-0710:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: UAJXA2 for IT-47-03 with DNS
#     timeslot9: UAJXA2 for IT-47-03 with DNS
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CTJ1A2 for SE-47-01 with DQU
#     timeslot6: CII1C2 for DS-47-02 with DAM
#     timeslot7: CII1C2 for DS-47-02 with DAM
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: CTJ1A2 for IF-47-12 with ALZ
#     timeslot3: CTJ1A2 for IF-47-12 with ALZ
#     timeslot4: Free
#     timeslot5: CII1A3 for IT-47-04 with HMT
#     timeslot6: CII1A3 for IT-47-04 with HMT
#     timeslot7: CII1A3 for IT-47-04 with HMT
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: CSI1A2 for IF-47-04 with FAZ
#     timeslot12: CSI1A2 for IF-47-04 with FAZ
#   Thursday:
#     timeslot1: Free
#     timeslot2: CII1B3 for IF-47-04 with ALZ
#     timeslot3: CII1B3 for IF-47-04 with ALZ
#     timeslot4: CII1B3 for IF-47-04 with ALZ
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: UAJXA2 for SE-47-02 with EDW
#     timeslot11: UAJXA2 for SE-47-02 with EDW
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CII1A3 for DS-47-02 with DDR
#     timeslot6: CII1A3 for DS-47-02 with DDR
#     timeslot7: CII1A3 for DS-47-02 with DDR
#     timeslot8: CRI1A2 for IT-47-03 with DRB
#     timeslot9: CRI1A2 for IT-47-03 with DRB
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-0711:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CRI1A2 for DS-47-03 with EDW
#     timeslot10: CRI1A2 for DS-47-03 with EDW
#     timeslot11: Free
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: UAJXA2 for DS-47-03 with IDV
#     timeslot9: UAJXA2 for DS-47-03 with IDV
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CRI1A2 for IF-47-07 with EDW
#     timeslot5: CRI1A2 for IF-47-07 with EDW
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Thursday:
#     timeslot1: CSI1A2 for IF-47-02 with ALZ
#     timeslot2: CSI1A2 for IF-47-02 with ALZ
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CII1B3 for IF-47-INT with HMT
#     timeslot8: CII1B3 for IF-47-INT with HMT
#     timeslot9: CTJ1A2 for SE-47-02 with DRI
#     timeslot10: CTJ1A2 for SE-47-02 with DRI
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: CII1C2 for IF-47-INT with IND
#     timeslot12: CII1C2 for IF-47-INT with IND
#   Saturday:
#     timeslot1: CII1B3 for IF-47-05 with ADE
#     timeslot2: CII1B3 for IF-47-05 with ADE
#     timeslot3: CII1B3 for IF-47-05 with ADE
#     timeslot4: CII1A3 for IF-47-09 with JDN
#     timeslot5: CII1A3 for IF-47-09 with JDN
#     timeslot6: CII1A3 for IF-47-09 with JDN
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: UAJXA2 for IT-47-02 with FAZ
#     timeslot12: UAJXA2 for IT-47-02 with FAZ
#
# Timetable for TULT-0714:
#   Monday:
#     timeslot1: Free
#     timeslot2: CII1C2 for IF-47-04 with BTG
#     timeslot3: CII1C2 for IF-47-04 with BTG
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1B3 for IF-47-02 with DVI
#     timeslot4: UKJXB2 for IT-47-01 with HMT
#     timeslot5: UKJXB2 for IT-47-01 with HMT
#     timeslot6: UAJXA2 for SE-47-01 with DQU
#     timeslot7: UAJXA2 for SE-47-01 with DQU
#     timeslot8: CTJ1A2 for IF-47-04 with ADE
#     timeslot9: CTJ1A2 for IF-47-04 with ADE
#     timeslot10: CSI1A2 for IF-47-12 with DRB
#     timeslot11: CSI1A2 for IF-47-12 with DRB
#     timeslot12: Free
#   Wednesday:
#     timeslot1: CSI1A2 for IF-47-11 with ALZ
#     timeslot2: CSI1A2 for IF-47-11 with ALZ
#     timeslot3: CII1A3 for IF-47-07 with DRI
#     timeslot4: CRI1B3 for IT-47-02 with APY
#     timeslot5: CRI1B3 for IT-47-02 with APY
#     timeslot6: CRI1B3 for IT-47-02 with APY
#     timeslot7: CSI1A2 for IT-47-02 with DYA
#     timeslot8: CSI1A2 for IT-47-02 with DYA
#     timeslot9: CRI1B3 for SE-47-03 with FAZ
#     timeslot10: UKJXB2 for SE-47-04 with IND
#     timeslot11: UKJXB2 for SE-47-04 with IND
#     timeslot12: Free
#   Thursday:
#     timeslot1: CII1B3 for IT-47-02 with DWF
#     timeslot2: CII1B3 for IT-47-02 with DWF
#     timeslot3: CII1B3 for IT-47-02 with DWF
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CTJ1A2 for IF-47-01 with DWF
#     timeslot9: CTJ1A2 for IF-47-01 with DWF
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CII1B3 for IF-47-03 with IMD
#     timeslot10: CII1B3 for IF-47-03 with IMD
#     timeslot11: CII1B3 for IF-47-03 with IMD
#     timeslot12: Free
#   Saturday:
#     timeslot1: CII1B3 for IT-47-03 with SBG
#     timeslot2: CII1B3 for IT-47-03 with SBG
#     timeslot3: CII1B3 for IT-47-03 with SBG
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CRI1B3 for SE-47-01 with DOK
#     timeslot9: CRI1B3 for SE-47-01 with DOK
#     timeslot10: CRI1B3 for SE-47-01 with DOK
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-0715:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: CII1E3 for IF-47-03 with ASA
#     timeslot4: CII1E3 for IF-47-03 with ASA
#     timeslot5: CII1E3 for IF-47-03 with ASA
#     timeslot6: Free
#     timeslot7: CII1E3 for IF-47-02 with EDW
#     timeslot8: CII1E3 for IF-47-02 with EDW
#     timeslot9: CII1A3 for IF-47-10 with JDN
#     timeslot10: CII1A3 for IF-47-10 with JDN
#     timeslot11: CII1A3 for IF-47-10 with JDN
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CII1E3 for IF-47-05 with FAZ
#     timeslot5: CII1E3 for IF-47-05 with FAZ
#     timeslot6: CRI1A2 for IF-47-INT with DOK
#     timeslot7: CRI1A2 for IF-47-INT with DOK
#     timeslot8: CII1A3 for DS-47-01 with FKI
#     timeslot9: CII1A3 for DS-47-01 with FKI
#     timeslot10: CII1A3 for DS-47-01 with FKI
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: CTJ1A2 for IT-47-03 with DOK
#     timeslot2: CTJ1A2 for IT-47-03 with DOK
#     timeslot3: CII1B3 for IF-47-10 with DWD
#     timeslot4: CII1B3 for IF-47-10 with DWD
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: CRI1A2 for IF-47-04 with DNS
#     timeslot11: CRI1A2 for IF-47-04 with DNS
#     timeslot12: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CSI1A2 for DS-47-03 with APY
#     timeslot5: CSI1A2 for DS-47-03 with APY
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CII1B3 for IT-47-01 with DVI
#     timeslot9: CII1B3 for IT-47-01 with DVI
#     timeslot10: CTJ1A2 for IT-47-02 with ALH
#     timeslot11: CTJ1A2 for IT-47-02 with ALH
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: CII1E3 for IF-47-09 with ALZ
#     timeslot3: CII1E3 for IF-47-09 with ALZ
#     timeslot4: CII1E3 for IF-47-09 with ALZ
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: UAJXA2 for IF-47-04 with IDV
#     timeslot8: UAJXA2 for IF-47-04 with IDV
#     timeslot9: Free
#     timeslot10: UAJXA2 for DS-47-02 with EDW
#     timeslot11: UAJXA2 for DS-47-02 with EDW
#     timeslot12: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: CII1E3 for IF-47-12 with IND
#     timeslot3: CII1E3 for IF-47-12 with IND
#     timeslot4: CII1E3 for IF-47-12 with IND
#     timeslot5: CII1B3 for SE-47-02 with IDV
#     timeslot6: CII1B3 for SE-47-02 with IDV
#     timeslot7: CII1B3 for SE-47-02 with IDV
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: CII1E3 for IF-47-08 with DVI
#     timeslot11: CII1E3 for IF-47-08 with DVI
#     timeslot12: CII1E3 for IF-47-08 with DVI
#
# Timetable for TULT-0716:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CII1E3 for SE-47-03 with AZN
#     timeslot9: CII1E3 for SE-47-03 with AZN
#     timeslot10: CII1E3 for SE-47-03 with AZN
#     timeslot11: Free
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: UAJXA2 for SE-47-04 with KMM
#     timeslot5: UAJXA2 for SE-47-04 with KMM
#     timeslot6: Free
#     timeslot7: CRI1A2 for SE-47-03 with DQU
#     timeslot8: CRI1A2 for SE-47-03 with DQU
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CII1B3 for IF-47-01 with DAM
#     timeslot5: CII1B3 for IF-47-01 with DAM
#     timeslot6: CII1B3 for IF-47-01 with DAM
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: CTJ1A2 for IF-47-08 with IDV
#     timeslot2: CTJ1A2 for IF-47-08 with IDV
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: UAJXA2 for IF-47-07 with JDN
#     timeslot10: UAJXA2 for IF-47-07 with JDN
#     timeslot11: UKJXB2 for SE-47-02 with CDF
#     timeslot12: UKJXB2 for SE-47-02 with CDF
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CRI1A2 for SE-47-04 with DVI
#     timeslot8: CRI1A2 for SE-47-04 with DVI
#     timeslot9: CII1C2 for IF-47-03 with BTG
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-1507:
#   Monday:
#     timeslot1: Free
#     timeslot2: CII1B3 for IF-47-12 with PHG
#     timeslot3: CII1B3 for IF-47-12 with PHG
#     timeslot4: CII1B3 for IF-47-12 with PHG
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: UAJXA2 for SE-47-03 with HMT
#     timeslot4: UAJXA2 for SE-47-03 with HMT
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: CII1B3 for IF-47-06 with DRI
#     timeslot11: CII1B3 for IF-47-06 with DRI
#     timeslot12: CII1B3 for IF-47-06 with DRI
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: CII1E3 for IF-47-07 with IMD
#     timeslot7: CII1E3 for IF-47-07 with IMD
#     timeslot8: CII1E3 for IF-47-07 with IMD
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CII1B3 for DS-47-01 with ADE
#     timeslot10: CII1B3 for DS-47-01 with ADE
#     timeslot11: CII1B3 for DS-47-01 with ADE
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: CRI1A2 for IF-47-02 with DNS
#     timeslot3: CRI1A2 for IF-47-02 with DNS
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: CII1A3 for SE-47-01 with DRB
#     timeslot9: CII1A3 for SE-47-01 with DRB
#     timeslot10: CII1A3 for SE-47-01 with DRB
#     timeslot11: Free
#     timeslot12: Free
#   Saturday:
#     timeslot1: CRI1B3 for IF-47-04 with DWF
#     timeslot2: CRI1B3 for IF-47-04 with DWF
#     timeslot3: CRI1B3 for IF-47-04 with DWF
#     timeslot4: CTJ1A2 for IF-47-11 with DYA
#     timeslot5: CTJ1A2 for IF-47-11 with DYA
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-1509:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: UAJXA2 for IF-47-08 with BTG
#     timeslot5: UAJXA2 for IF-47-08 with BTG
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: CII1A3 for SE-47-03 with DWF
#     timeslot8: CII1A3 for SE-47-03 with DWF
#     timeslot9: CII1A3 for SE-47-03 with DWF
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: CSI1A2 for SE-47-03 with DWF
#     timeslot2: CSI1A2 for SE-47-03 with DWF
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Saturday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Timetable for TULT-1510:
#   Monday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: CRI1B3 for IF-47-09 with DAM
#     timeslot5: CRI1B3 for IF-47-09 with DAM
#     timeslot6: CRI1B3 for IF-47-09 with DAM
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Tuesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Wednesday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: CRI1B3 for IF-47-10 with FMH
#     timeslot6: CRI1B3 for IF-47-10 with FMH
#     timeslot7: CRI1B3 for IF-47-10 with FMH
#     timeslot8: CII1B3 for SE-47-01 with APY
#     timeslot9: CII1B3 for SE-47-01 with APY
#     timeslot10: CII1B3 for SE-47-01 with APY
#     timeslot11: CII1A3 for IF-47-12 with IPL
#     timeslot12: Free
#   Thursday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: CII1E3 for DS-47-01 with DQU
#     timeslot10: CII1E3 for DS-47-01 with DQU
#     timeslot11: CII1E3 for DS-47-01 with DQU
#     timeslot12: Free
#   Friday:
#     timeslot1: Free
#     timeslot2: Free
#     timeslot3: Free
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: Free
#     timeslot7: Free
#     timeslot8: Free
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#   Saturday:
#     timeslot1: CRI1B3 for IF-47-12 with ASA
#     timeslot2: CRI1B3 for IF-47-12 with ASA
#     timeslot3: CRI1B3 for IF-47-12 with ASA
#     timeslot4: Free
#     timeslot5: Free
#     timeslot6: CII1C2 for IF-47-11 with DRI
#     timeslot7: CRI1A2 for SE-47-02 with DVI
#     timeslot8: CRI1A2 for SE-47-02 with DVI
#     timeslot9: Free
#     timeslot10: Free
#     timeslot11: Free
#     timeslot12: Free
#
# Best Fitness: 1057.5
